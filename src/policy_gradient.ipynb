# %%
from environment import GridWorld
from agent import Agent
import matplotlib.pyplot as plt

# %%
env=GridWorld()

# %%
# For sigma = 0.1
agent = Agent(env, 0.1)
mean_and_standard_deviation_per_trial = agent.hill_search()
# Plotting the mean and standard deviation per trial
plt.plot(mean_and_standard_deviation_per_trial[0], label='Mean')
plt.plot(mean_and_standard_deviation_per_trial[1], label='Standard Deviation')
plt.xlabel('Trials')
plt.ylabel('Mean and Standard Deviation')
plt.title('Mean and Standard Deviation per trial for sigma = 0.1')
plt.legend()
# Out:
# Progress |██████████████████████████████████████████████████| 100.0% Complete

# %%
# For sigma = 0.2
agent = Agent(env, 0.2)
mean_and_standard_deviation_per_trial = agent.hill_search()
# Plotting the mean and standard deviation per trial
plt.plot(mean_and_standard_deviation_per_trial[0], label='Mean')
plt.plot(mean_and_standard_deviation_per_trial[1], label='Standard Deviation')
plt.xlabel('Trials')
plt.ylabel('Mean and Standard Deviation')
plt.title('Mean and Standard Deviation per trial for sigma = 0.2')
plt.legend()
# Out:
# Progress |██████████████████████████████████████████████████| 100.0% Complete

# %%
# For sigma = 0.3
agent = Agent(env, 0.3)
mean_and_standard_deviation_per_trial = agent.hill_search()
# Plotting the mean and standard deviation per trial in different plots
plt.plot(mean_and_standard_deviation_per_trial[0], label='Mean')
plt.plot(mean_and_standard_deviation_per_trial[1], label='Standard Deviation')
plt.xlabel('Trials')
plt.ylabel('Mean and Standard Deviation')
plt.title('Mean and Standard Deviation per trial for sigma = 0.3')
plt.legend()
# Out:
# Progress |██████████████████████████████████████████████████| 100.0% Complete

# %%
# For sigma = 0.4
agent = Agent(env, 0.4)
mean_and_standard_deviation_per_trial = agent.hill_search()
# Plotting the mean and standard deviation per trial
plt.plot(mean_and_standard_deviation_per_trial[0], label='Mean')
plt.plot(mean_and_standard_deviation_per_trial[1], label='Standard Deviation')
plt.xlabel('Trials')
plt.ylabel('Mean and Standard Deviation')
plt.title('Mean and Standard Deviation per trial for sigma = 0.4')
plt.legend()
# Out:
# Progress |██████████████████████████████████████████████████| 100.0% Complete

# %%
# For sigma = 0.5
agent = Agent(env, 0.5)
mean_and_standard_deviation_per_trial = agent.hill_search()
# Plotting the mean and standard deviation per trial
plt.plot(mean_and_standard_deviation_per_trial[0], label='Mean')
plt.plot(mean_and_standard_deviation_per_trial[1], label='Standard Deviation')
plt.xlabel('Trials')
plt.ylabel('Mean and Standard Deviation')
plt.title('Mean and Standard Deviation per trial for sigma = 0.5')
plt.legend()
# Out:
# Progress |██████████████████████████████████████████████████| 100.0% Complete

# %%
# For sigma = 0.6
agent = Agent(env, 0.6)
mean_and_standard_deviation_per_trial = agent.hill_search()
# Plotting the mean and standard deviation per trial
plt.plot(mean_and_standard_deviation_per_trial[0], label='Mean')
plt.plot(mean_and_standard_deviation_per_trial[1], label='Standard Deviation')
plt.xlabel('Trials')
plt.ylabel('Mean and Standard Deviation')
plt.title('Mean and Standard Deviation per trial for sigma = 0.6')
plt.legend()
# Out:
# Progress |██████████████████████████████████████████████████| 100.0% Complete

# %%
# For sigma = 0.7
agent = Agent(env, 0.7)
mean_and_standard_deviation_per_trial = agent.hill_search()
# Plotting the mean and standard deviation per trial
plt.plot(mean_and_standard_deviation_per_trial[0], label='Mean')
plt.plot(mean_and_standard_deviation_per_trial[1], label='Standard Deviation')
plt.xlabel('Trials')
plt.ylabel('Mean and Standard Deviation')
plt.title('Mean and Standard Deviation per trial for sigma = 0.7')
plt.legend()
# Out:
# Progress |██████████████████████████████████████████████████| 100.0% Complete

# %%
# For sigma = 0.8
agent = Agent(env, 0.8)
mean_and_standard_deviation_per_trial = agent.hill_search()
# Plotting the mean and standard deviation per trial
plt.plot(mean_and_standard_deviation_per_trial[0], label='Mean')
plt.plot(mean_and_standard_deviation_per_trial[1], label='Standard Deviation')
plt.xlabel('Trials')
plt.ylabel('Mean and Standard Deviation')
plt.title('Mean and Standard Deviation per trial for sigma = 0.8')
plt.legend()
# Out:
# Progress |██████████████████████████████████████████████████| 100.0% Complete

# %%
# For sigma = 0.9
agent = Agent(env, 0.9)
mean_and_standard_deviation_per_trial = agent.hill_search()
# Plotting the mean and standard deviation per trial
plt.plot(mean_and_standard_deviation_per_trial[0], label='Mean')
plt.plot(mean_and_standard_deviation_per_trial[1], label='Standard Deviation')
plt.xlabel('Trials')
plt.ylabel('Mean and Standard Deviation')
plt.title('Mean and Standard Deviation per trial for sigma = 0.9')
plt.legend()
# Out:
# Progress |██████████████████████████████████████████████████| 100.0% Complete

# %% [markdown]
# ### Setting sigma = 0.8 seems to give us a good gain overall

# %%
# For sigma = 0.8
agent = Agent(env, 0.8)
mean_and_standard_deviation_per_trial = agent.hill_search()

# %%
plt.figure(figsize=(20, 6))
# Plotting the error bars for the mean and standard deviation per trial
plt.errorbar(
    range(1, len(mean_and_standard_deviation_per_trial[0]) + 1),
    y=mean_and_standard_deviation_per_trial[0],
    yerr=mean_and_standard_deviation_per_trial[1],
    fmt=".",
    capsize=5,
)
# Out:
# <ErrorbarContainer object of 3 artists>
